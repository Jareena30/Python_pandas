# %%
#Create Panel From 3D ndarray
# creating an empty panel
import pandas as pd
import numpy as np

data = np.random.rand(2,4,5)
p = pd.Panel(data)
print (p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-aeae61dd735b> in <cell line: 7>()
#       5
#       6 data = np.random.rand(2,4,5)
# ----> 7 p = pd.Panel(data)
#       8 print (p)
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
#creating an empty panel
import pandas as pd
import numpy as np

data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
   'Item2' : pd.DataFrame(np.random.randn(4, 2))}
p = pd.Panel(data)
print (p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-53953b77652e> in <cell line: 7>()
#       5 data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
#       6    'Item2' : pd.DataFrame(np.random.randn(4, 2))}
# ----> 7 p = pd.Panel(data)
#       8 print (p)
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
#Create an Empty Panel
import pandas as pd
p = pd.Panel()
print (p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b9eb9429e3c7> in <cell line: 3>()
#       1 #Create an Empty Panel
#       2 import pandas as pd
# ----> 3 p = pd.Panel()
#       4 print (p)
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
#Selecting the Data from Panel
#Using Items

# creating an empty panel
import pandas as pd
import numpy as np
data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
   'Item2' : pd.DataFrame(np.random.randn(4, 2))}
p = pd.Panel(data)
print (p['Item1'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c68bf131ae8a> in <cell line: 9>()
#       7 data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
#       8    'Item2' : pd.DataFrame(np.random.randn(4, 2))}
# ----> 9 p = pd.Panel(data)
#      10 print (p['Item1'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
#Using major_axis
#Data can be accessed using the method panel.major_axis(index).

import pandas as pd
import numpy as np
data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
   'Item2' : pd.DataFrame(np.random.randn(4, 2))}
p = pd.Panel(data)
print (p.major_xs(1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-046d401a2e9a> in <cell line: 8>()
#       6 data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
#       7    'Item2' : pd.DataFrame(np.random.randn(4, 2))}
# ----> 8 p = pd.Panel(data)
#       9 print (p.major_xs(1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
#Using major_axis
#Data can be accessed using the method panel.major_axis(index).

 # creating an empty panel
import pandas as pd
import numpy as np
data = {'Item1' : pd.DataFrame(np.random.randn(4, 3)),
   'Item2' : pd.DataFrame(np.random.randn(4, 2))}
p = pd.Panel(data)
print p.major_xs(1)
# Out:
#   File "<ipython-input-1-fb965ec4bec5>", line 10
#     print p.major_xs(1)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
